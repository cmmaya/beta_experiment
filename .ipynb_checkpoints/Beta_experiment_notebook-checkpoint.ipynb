# %%
# Beta experiment

## Introduction
This experiment utilizes historical prices data from the top20 erc20 tokens fetched from CoinMarketCap API. Primarly, to construct a portfolio of assets with weights $$w$_i$ based on the Minimization of the risk:
 $$\min_w w^T \Sigma w + (\beta_\mathsf{X}-1)^2$$

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import yfinance as yf

import os
import requests
import pandas as pd

def fetch_top_erc20_tokens(limit=25):
    url = "https://api.coingecko.com/api/v3/coins/markets"
    params = {
        'vs_currency': 'eth',
        'order': 'market_cap_desc',
        'per_page': limit,
        'page': 1,
        'sparkline': 'false',
        'price_change_percentage': '24h'
    }
    response = requests.get(url, params=params)
    data = response.json()
    return pd.DataFrame(data)

def fetch_top_erc20_tokens_from_coinmarketcap(limit=50):
    api_key = os.getenv('COINMARKETCAP_API_KEY')  # Fetch the API key from environment variables
    
    if not api_key:
        raise Exception("API key not found. Please set the COINMARKETCAP_API_KEY environment variable.")
    
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    headers = {
        'Accepts': 'application/json',
        'X-CMC_PRO_API_KEY': api_key,
    }
    params = {
        'start': '1',
        'limit': '200',  # Fetch a larger number and then filter down to ERC-20 tokens
        'convert': 'USD',
    }
    
    response = requests.get(url, headers=headers, params=params)
    
    # Check if the response was successful
    if response.status_code != 200:
        raise Exception(f"Error fetching data from CoinMarketCap API: {response.status_code}, {response.text}")
    
    data = response.json()
    
    # Check if 'data' key is in the JSON response
    if 'data' not in data:
        raise KeyError("'data' key not found in the API response")
    
    # Extract ERC-20 tokens and ETH
    erc20_tokens = []
    eth_token = None
    for token in data['data']:
        if token['symbol'] == 'ETH':
            eth_token = token
        else:
            erc20_tokens.append(token)
    
    # Ensure ETH is always included in the list
    if eth_token:
        erc20_tokens.insert(0, eth_token)
    
    # Sort by market cap to get the top `limit` tokens, ensuring ETH is always included
    erc20_tokens = sorted(erc20_tokens, key=lambda x: x['quote']['USD']['market_cap'], reverse=True)
    erc20_tokens = erc20_tokens[:limit]
    
    # Convert to DataFrame
    df = pd.DataFrame(erc20_tokens)
    
    return df
top_tokens = fetch_top_erc20_tokens_from_coinmarketcap()
top_tokens
# Out:
#        id               name symbol                  slug  num_market_pairs  \
# 0       1            Bitcoin    BTC               bitcoin             11078
# 1    1027           Ethereum    ETH              ethereum              9015
# 2     825        Tether USDt   USDT                tether             87300
# 3    1839                BNB    BNB                   bnb              2172
# 4    5426             Solana    SOL                solana               668
# 5    3408               USDC   USDC              usd-coin             19494
# 6      52                XRP    XRP                   xrp              1332
# 7      74           Dogecoin   DOGE              dogecoin               974
# 8    2010            Cardano    ADA               cardano              1187
# 9   11419            Toncoin    TON               toncoin               380
# 10   5994          Shiba Inu   SHIB             shiba-inu               826
# 11   5805          Avalanche   AVAX             avalanche               733
# 12   1975          Chainlink   LINK             chainlink              1785
# 13   6636           Polkadot    DOT          polkadot-new               773
# 14   1958               TRON    TRX                  tron               984
# 15   1831       Bitcoin Cash    BCH          bitcoin-cash               893
# 16   6535      NEAR Protocol   NEAR         near-protocol               414
# 17   3890            Polygon  MATIC               polygon              1395
# 18   7083            Uniswap    UNI               uniswap              1033
# 19      2           Litecoin    LTC              litecoin              1198
# 20  24478               Pepe   PEPE                  pepe               383
# 21   8916  Internet Computer    ICP     internet-computer               248
# 22   3957       UNUS SED LEO    LEO          unus-sed-leo                46
# 23   4943                Dai    DAI  multi-collateral-dai              3253
# 24   1321   Ethereum Classic    ETC      ethereum-classic               531
# 25  21794              Aptos    APT                 aptos               384
# 26   5690             Render   RNDR                render               408
# 27   4642             Hedera   HBAR                hedera               270
# 28  28752          dogwifhat    WIF             dogwifhat               383
# 29   3794             Cosmos   ATOM                cosmos               767
# 30  11841           Arbitrum    ARB              arbitrum               921
# 31  20396              Kaspa    KAS                 kaspa               119
# 32  10603          Immutable    IMX           immutable-x               286
# 33  27075             Mantle    MNT                mantle                74
# 34   2280           Filecoin    FIL              filecoin               484
# 35   3635             Cronos    CRO                cronos               240
# 36    512            Stellar    XLM               stellar               593
# 37   6719          The Graph    GRT             the-graph               479
# 38  26081  First Digital USD  FDUSD     first-digital-usd               305
# 39   4847             Stacks    STX                stacks               180
# 40   5632            Arweave     AR               arweave               143
# 41  22974          Bittensor    TAO             bittensor                65
# 42   3897                OKB    OKB                   okb               123
# 43  11840           Optimism     OP     optimism-ethereum               534
# 44    328             Monero    XMR                monero               285
# 45   3077            VeChain    VET               vechain               286
# 46   1518              Maker    MKR                 maker               479
# 47  20947                Sui    SUI                   sui               264
# 48  10804              FLOKI  FLOKI             floki-inu               488
# 49   7226          Injective    INJ             injective               379
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2020-04-10T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2013-08-04T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2017-10-01T00:00:00.000Z
# 9   2021-08-26T13:40:22.000Z
# 10  2020-08-01T00:00:00.000Z
# 11  2020-07-13T00:00:00.000Z
# 12  2017-09-20T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2017-09-13T00:00:00.000Z
# 15  2017-07-23T00:00:00.000Z
# 16  2020-08-11T00:00:00.000Z
# 17  2019-04-28T00:00:00.000Z
# 18  2020-09-17T00:00:00.000Z
# 19  2013-04-28T00:00:00.000Z
# 20  2023-04-17T06:18:08.000Z
# 21  2021-03-23T00:00:00.000Z
# 22  2019-05-21T00:00:00.000Z
# 23  2019-11-22T00:00:00.000Z
# 24  2016-07-24T00:00:00.000Z
# 25  2022-10-19T01:50:25.000Z
# 26  2020-06-11T00:00:00.000Z
# 27  2019-09-17T00:00:00.000Z
# 28  2023-12-19T09:08:50.000Z
# 29  2019-03-14T00:00:00.000Z
# 30  2023-03-23T12:50:11.000Z
# 31  2022-06-01T00:03:58.000Z
# 32  2021-06-24T00:00:00.000Z
# 33  2023-07-17T11:00:31.000Z
# 34  2017-12-13T00:00:00.000Z
# 35  2018-12-14T00:00:00.000Z
# 36  2014-08-05T00:00:00.000Z
# 37  2020-12-17T00:00:00.000Z
# 38  2023-07-26T04:26:40.000Z
# 39  2019-10-28T00:00:00.000Z
# 40  2020-05-27T00:00:00.000Z
# 41  2023-03-06T05:20:00.000Z
# 42  2019-04-30T00:00:00.000Z
# 43  2022-05-31T16:19:46.000Z
# 44  2014-05-21T00:00:00.000Z
# 45  2017-08-22T00:00:00.000Z
# 46  2017-01-29T00:00:00.000Z
# 47  2022-07-12T08:03:11.000Z
# 48  2021-07-09T00:00:00.000Z
# 49  2020-09-29T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, avalanch...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 5   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 6   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 9   [pos, layer-1, ftx-bankruptcy-estate, dwf-labs...           NaN
# 10      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
# 11  [defi, smart-contracts, three-arrows-capital-p...  7.157487e+08
# 12  [platform, defi, oracles, smart-contracts, sub...  1.000000e+09
# 13  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 14  [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 15  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 16  [platform, ai-big-data, staking, coinbase-vent...           NaN
# 17  [pos, platform, enterprise-solutions, zero-kno...  1.000000e+10
# 18  [decentralized-exchange-dex-token, defi, dao, ...  1.000000e+09
# 19        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 20                                            [memes]  4.206900e+14
# 21  [platform, distributed-computing, collectibles...           NaN
# 22  [marketplace, centralized-exchange, discount-t...           NaN
# 23  [defi, stablecoin, asset-backed-stablecoin, et...           NaN
# 24  [mineable, pow, ethash, platform, smart-contra...  2.107000e+08
# 25  [binance-labs-portfolio, aptos-ecosystem, circ...           NaN
# 26  [art, media, vr-ar, ai-big-data, distributed-c...  5.368709e+08
# 27  [dag, marketplace, enterprise-solutions, payme...  5.000000e+10
# 28        [memes, solana-ecosystem, doggone-doggerel]           NaN
# 29  [platform, cosmos-ecosystem, content-creation,...           NaN
# 30  [scaling, dao, dapp, ethereum-ecosystem, polyc...           NaN
# 31  [mineable, dag, pow, store-of-value, polychain...  2.870000e+10
# 32  [collectibles-nfts, zero-knowledge-proofs, gam...  2.000000e+09
# 33  [ethereum-ecosystem, layer-2, dwf-labs-portfolio]  6.219317e+09
# 34  [mineable, distributed-computing, filesharing,...           NaN
# 35  [medium-of-exchange, cosmos-ecosystem, central...  3.026301e+10
# 36  [medium-of-exchange, enterprise-solutions, dec...  5.000181e+10
# 37  [ai-big-data, enterprise-solutions, defi, coin...           NaN
# 38  [stablecoin, ethereum-ecosystem, binance-smart...           NaN
# 39  [mineable, platform, collectibles-nfts, defi, ...  1.818000e+09
# 40  [distributed-computing, filesharing, storage, ...  6.600000e+07
# 41  [ai-big-data, distributed-computing, oracles, ...  2.100000e+07
# 42  [marketplace, centralized-exchange, discount-t...           NaN
# 43  [layer-2, optimism-ecosystem, modular-blockchain]  4.294967e+09
# 44  [mineable, pow, medium-of-exchange, privacy, r...           NaN
# 45  [logistics, data-provenance, iot, smart-contra...  8.671263e+10
# 46  [store-of-value, defi, dao, polychain-capital-...  1.005577e+06
# 47  [binance-launchpool, coinbase-ventures-portfol...  1.000000e+10
# 48  [gaming, memes, metaverse, doggone-doggerel, p...           NaN
# 49  [pos, platform, cosmos-ecosystem, ai-big-data,...           NaN
#
#     circulating_supply  total_supply  infinite_supply  \
# 0         1.970558e+07  1.970558e+07            False
# 1         1.201397e+08  1.201397e+08             True
# 2         1.119638e+11  1.150866e+11             True
# 3         1.475854e+08  1.475854e+08            False
# 4         4.596199e+08  5.771017e+08             True
# 5         3.219701e+10  3.219701e+10            False
# 6         5.543048e+10  9.998759e+10            False
# 7         1.445037e+11  1.445037e+11             True
# 8         3.569827e+10  3.692543e+10            False
# 9         2.411271e+09  5.107099e+09             True
# 10        5.892718e+14  5.895200e+14            False
# 11        3.929889e+08  4.423353e+08            False
# 12        5.871000e+08  1.000000e+09            False
# 13        1.437953e+09  1.437953e+09             True
# 14        8.738518e+10  8.738526e+10             True
# 15        1.971266e+07  1.971266e+07            False
# 16        1.080714e+09  1.193127e+09            False
# 17        9.907385e+09  1.000000e+10            False
# 18        5.989303e+08  1.000000e+09            False
# 19        7.458735e+07  8.400000e+07            False
# 20        4.206899e+14  4.206899e+14            False
# 21        4.643706e+08  5.189952e+08             True
# 22        9.263002e+08  9.852395e+08            False
# 23        5.347889e+09  5.347889e+09             True
# 24        1.473117e+08  2.107000e+08            False
# 25        4.365085e+08  1.098389e+09             True
# 26        3.886440e+08  5.320709e+08            False
# 27        3.574998e+10  5.000000e+10            False
# 28        9.989059e+08  9.989059e+08            False
# 29        3.909307e+08  3.909307e+08             True
# 30        2.896440e+09  1.000000e+10            False
# 31        2.378368e+10  2.378368e+10            False
# 32        1.482345e+09  2.000000e+09            False
# 33        3.264442e+09  6.219317e+09            False
# 34        5.573850e+08  1.960460e+09            False
# 35        2.657156e+10  3.000000e+10            False
# 36        2.900747e+10  5.000179e+10            False
# 37        9.509177e+09  1.079838e+10            False
# 38        2.916157e+09  2.916157e+09            False
# 39        1.462001e+09  1.818000e+09            False
# 40        6.545418e+07  6.545418e+07            False
# 41        6.854168e+06  6.854168e+06            False
# 42        6.000000e+07  3.000000e+08            False
# 43        1.086890e+09  4.294967e+09            False
# 44        1.844335e+07  1.844335e+07             True
# 45        7.271452e+10  8.598504e+10            False
# 46        9.276552e+05  9.776310e+05            False
# 47        2.339197e+09  1.000000e+10            False
# 48        9.558707e+12  9.691324e+12            False
# 49        9.340000e+07  1.000000e+08            False
#
#                                              platform  cmc_rank  \
# 0                                                None         1
# 1                                                None         2
# 2   {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         3
# 3                                                None         4
# 4                                                None         5
# 5   {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...         6
# 6                                                None         7
# 7                                                None         8
# 8                                                None         9
# 9                                                None        10
# 10  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        11
# 11                                               None        12
# 12  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        13
# 13                                               None        14
# 14                                               None        15
# 15                                               None        16
# 16                                               None        17
# 17                                               None        18
# 18  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        19
# 19                                               None        20
# 20  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        21
# 21  {'id': 8916, 'name': 'ICP', 'symbol': 'ICP', '...        22
# 22  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        23
# 23  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        24
# 24                                               None        25
# 25                                               None        26
# 26  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        27
# 27                                               None        28
# 28  {'id': 5426, 'name': 'Solana', 'symbol': 'SOL'...        29
# 29                                               None        30
# 30  {'id': 11841, 'name': 'Arbitrum', 'symbol': 'A...        31
# 31                                               None        32
# 32  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        33
# 33  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        34
# 34                                               None        35
# 35                                               None        36
# 36                                               None        37
# 37  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        38
# 38  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        39
# 39                                               None        40
# 40                                               None        41
# 41                                               None        42
# 42  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        43
# 43  {'id': 11840, 'name': 'Optimism', 'symbol': 'O...        44
# 44                                               None        45
# 45                                               None        46
# 46  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        47
# 47  {'id': 20947, 'name': 'Sui Network', 'symbol':...        48
# 48  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ET...        49
# 49  {'id': 7226, 'name': 'Injective', 'symbol': 'I...        50
#
#     self_reported_circulating_supply  self_reported_market_cap  tvl_ratio  \
# 0
# 41  {'USD': {'price': 407.0220825363519, 'volume_2...
# 42  {'USD': {'price': 45.68607509933761, 'volume_2...
# 43  {'USD': {'price': 2.500862490597441, 'volume_2...
# 44  {'USD': {'price': 145.7398480525351, 'volume_2...
# 45  {'USD': {'price': 0.03475027955275195, 'volume...
# 46  {'USD': {'price': 2683.0626565809384, 'volume_...
# 47  {'USD': {'price': 1.019714833419671, 'volume_2...
# 48  {'USD': {'price': 0.00024895969495228516, 'vol...
# 49  {'USD': {'price': 25.428633456347388, 'volume_...

# %%
from binance import Client
import pandas as pd
from datetime import datetime, timedelta
import time

# Initialize the Binance client
# Replace 'YOUR_API_KEY' and 'YOUR_API_SECRET' with your actual Binance API key and secret
client = Client(api_key='bucKUSO8lvKBoUgg9Fjs9VvPK8S6vgiONoKYeJFVOQKxVWIbSQzzwuC7i9x8KBwb', api_secret='PWQ3HY0uPRNnLzOC28W5CFca6iqokcMDDbae3wBrcDNIfRMlQ3XaI7YwtcduTqnB')

# Define the function to get historical data
def get_historical_data(symbol, start_date):
    start_str = start_date.strftime('%d %b %Y %H:%M:%S')
    klines = client.get_historical_klines(symbol, Client.KLINE_INTERVAL_1DAY, start_str)
    data = pd.DataFrame(klines, columns=[
        'timestamp', 'open', 'high', 'low', 'close', 'volume', 
        'close_time', 'quote_asset_volume', 'number_of_trades', 
        'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'
    ])
    data['timestamp'] = pd.to_datetime(data['timestamp'], unit='ms')
    data.set_index('timestamp', inplace=True)
    data = data[['close']].astype(float)
    return data

# List of cryptocurrency symbols (Binance symbols)
symbols = ['BTCUSDT', 'ETHUSDT', 'BNBUSDT']  # Add more as needed

# Initialize dictionary to store data
aux = {}

# Fetch historical data for each symbol
for symbol in top_tokens.symbol:
    try:
        historical_data = get_historical_data(symbol+'USDT', datetime(2023, 1, 1))
        aux[symbol] = historical_data['close']
        time.sleep(1)  # Sleep to avoid hitting API rate limits
    except Exception as e:
        print(f"Error retrieving data for {symbol}: {e}")

# Convert dictionary to DataFrame
df = pd.DataFrame(aux)
print(df)
# Out:
# Error retrieving data for USDT: APIError(code=-1121): Invalid symbol.
# Error retrieving data for TON: APIError(code=-1121): Invalid symbol.
# Error retrieving data for LEO: APIError(code=-1121): Invalid symbol.
# Error retrieving data for KAS: APIError(code=-1121): Invalid symbol.
# Error retrieving data for MNT: APIError(code=-1121): Invalid symbol.
# Error retrieving data for CRO: APIError(code=-1121): Invalid symbol.
# Error retrieving data for OKB: APIError(code=-1121): Invalid symbol.
#                  BTC      ETH    BNB     SOL    USDC     XRP     DOGE     ADA  \
# timestamp
# 2023-01-01  16616.75  1200.34  244.4    9.99     NaN  0.3387  0.07024  0.2499
# 2023-01-02  16672.87  1214.00  245.2   11.28     NaN  0.3482  0.07140  0.2538
# 2023-01-03  16675.18  1214.55  246.1   13.37     NaN  0.3436  0.07049  0.2529
# 2023-01-04  16850.36  1256.90  258.9   13.43     NaN  0.3472  0.07311  0.2678
# 2023-01-05  16831.85  1251.24  256.7   13.43     NaN  0.3380  0.07152  0.2692
# ...              ...      ...    ...     ...     ...     ...      ...     ...
# 2024-05-26  68507.67  3826.47  600.2  163.41  1.0005  0.5283  0.16621  0.4581
# 2024-05-27  69436.43  3894.22  603.9  170.15  1.0007  0.5340  0.16908  0.4683
# 2024-05-28  68398.39  3844.69  601.7  168.68  1.0011  0.5287  0.16497  0.4576
# 2024-05-29  67652.42  3767.43  595.7  168.32  1.0013  0.5238  0.16386  0.4512
# 2024-05-30  68369.73  3767.14  595.6  168.51  1.0003  0.5219  0.16019  0.4481
#
#                 SHIB   AVAX  ...    STX      AR    TAO     OP    XMR      VET  \
# timestamp                    ...
# 2023-01-01  0.000008  10.87  ...  0.213   6.370    NaN  0.924  148.5  0.01605
# 2023-01-02  0.000008  11.16  ...  0.216   6.650    NaN  0.958  147.8  0.01616
# 2023-01-03  0.000008  11.38  ...  0.216   6.690    NaN  0.957  148.4  0.01609
# 2023-01-04  0.000008  12.08  ...  0.220   6.950    NaN  1.030  150.9  0.01660
# 2023-01-05  0.000008  11.74  ...  0.217   6.620    NaN  1.024  156.1  0.01624
# ...              ...    ...  ...    ...     ...    ...    ...    ...      ...
# 2024-05-26  0.000024  36.76  ...  1.973  38.434  435.9  2.530    NaN  0.03560
# 2024-05-27  0.000026  38.26  ...  2.077  40.324  438.0  2.587    NaN  0.03661
# 2024-05-28  0.000027  37.02  ...  1.983  38.091  418.8  2.548    NaN  0.03580
# 2024-05-29  0.000028  36.20  ...  1.936  39.067  395.3  2.494    NaN  0.03516
# 2024-05-30  0.000026  36.50  ...  1.947  43.253  405.5  2.492    NaN  0.03459
#
#                MKR     FLOKI     SUI     INJ
# timestamp
# 2023-01-01   514.0       NaN     NaN   1.274
# 2023-01-02   512.0       NaN     NaN   1.299
# 2023-01-03   505.0       NaN     NaN   1.305
# 2023-01-04   519.0       NaN     NaN   1.356
# 2023-01-05   527.0       NaN     NaN   1.357
# ...            ...       ...     ...     ...
# 2024-05-26  2832.0  0.000226  1.0419  24.830
# 2024-05-27  2766.0  0.000278  1.0743  25.750
# 2024-05-28  2718.0  0.000295  1.0303  26.240
# 2024-05-29  2688.0  0.000268  1.0165  26.420
# 2024-05-30  2679.0  0.000251  1.0193  25.470
#
# [516 rows x 43 columns]

# %%
df=pd.DataFrame(aux)

# eth=df['eth']
# df=df.drop(columns=['eth','steth','usdc','usdt','uni','rseth','reth', 'tia', 'usde', 'core', 'wld', 'arb', 'floki'])

eth=df['ETH']
df=df.drop(columns=['UNI','PEPE', 'DAI','STX'])

df = df.drop(columns=df.columns[df.columns.str.contains('ETH|USD')])

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

returns = df.pct_change()

# Compute daily return of Ethereum to use as the market return
eth_returns = eth.pct_change()

# Prepare to store beta values
betas = {}
means=[]
returns = returns.replace([np.nan, np.inf, -np.inf], 0)
eth_returns = eth_returns.replace([np.nan, np.inf, -np.inf], 0)

# Compute beta for each column (cryptocurrency) against ETH
for column in returns.columns:
    if column != 'eth':  # Skip calculating ETH's beta with itself
        covariance = returns[column].cov(eth_returns)
        variance = eth_returns.var()
        means.append(max(0,returns[column].mean()))

        beta = covariance / variance
        betas[column] = beta

# Plotting the betas
names = list(betas.keys())
values = list(betas.values())

plt.figure(figsize=(10, 5))
plt.bar(names, values)
plt.ylabel('Beta')
plt.title('Historical Beta of Cryptocurrencies Relative to ETH')
plt.xticks(rotation=45)
plt.show()

# %%
# Create DataFrame from the dictionary
beta_df = pd.DataFrame(list(betas.items()), columns=['Crypto', 'Beta'])

# Sort the DataFrame by 'Beta' in descending order
beta_df_sorted = beta_df.sort_values(by='Beta', ascending=False)
beta_df_sorted=beta_df_sorted.dropna()
beta_df_sorted.tail(20)
# Out:
#    Crypto      Beta
# 31    VET  0.947711
# 5     ADA  0.923912
# 9     DOT  0.919466
# 19   HBAR  0.915794
# 15    ICP  0.904900
# 6    SHIB  0.902530
# 8    LINK  0.862585
# 21   ATOM  0.832226
# 11    BCH  0.815223
# 14    LTC  0.803411
# 3     XRP  0.785847
# 25    XLM  0.776843
# 32    MKR  0.755897
# 0     BTC  0.736623
# 34    SUI  0.602674
# 1     BNB  0.555110
# 20    WIF  0.492752
# 10    TRX  0.428759
# 30    XMR  0.280114
# 28    TAO  0.194872

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize


risk_free_rate = 0.03
market_return = 0.04

# CAPM Expected Returns

# Simulated covariance matrix based on betas (scaled for demonstration)
# Normally, you'd calculate this based on historical returns data
cov_matrix = returns.cov()  # Simplified assumption
expected_returns=means

# Number of assets
num_assets = len(betas)

# Objective Functions
def portfolio_variance(weights):
    return weights.T @ cov_matrix @ weights

def portfolio_return(weights):
    return weights.T @ expected_returns

target_beta = 1.0

# Calculate portfolio beta as a function of weights
def portfolio_beta(weights):
    individual_betas = np.array(list(betas.values()))
    return np.dot(weights, individual_betas)

# Constraint to achieve the target beta
constraints = [
    {'type': 'eq', 'fun': lambda x: np.sum(x) - 1},  # Weights must sum to 1
    {'type': 'eq', 'fun': lambda x: (portfolio_beta(x) - target_beta)**2}  # Portfolio beta must meet target
]
bounds = tuple((0, 1) for asset in range(num_assets))

# Initial guess (equal weighting)

init_guess = np.ones(num_assets) / num_assets
# Portfolio optimization for minimum variance
opt_min_var = minimize(portfolio_variance, init_guess, method='SLSQP', bounds=bounds, constraints=constraints)
min_var_weights = opt_min_var.x

print("Weights for Minimum Variance Portfolio:")
print(min_var_weights)
print("Expected Return:", portfolio_return(min_var_weights))
print("Expected Variance:", portfolio_variance(min_var_weights))

# Portfolio optimization for maximum Sharpe Ratio (Risk-Free Rate: 1%)
constraints = [
    {'type': 'eq', 'fun': lambda x: np.sum(x) - 1},  # Weights must sum to 1
    {'type': 'eq', 'fun': lambda x: -(portfolio_beta(x) - target_beta)**2}  # Portfolio beta must meet target
]
def neg_sharpe_ratio(weights):
    return - (portfolio_return(weights) - risk_free_rate) / np.sqrt(portfolio_variance(weights))

opt_max_sharpe = minimize(neg_sharpe_ratio, init_guess, method='SLSQP', bounds=bounds, constraints=constraints)
max_sharpe_weights = opt_max_sharpe.x

print("\nWeights for Maximum Sharpe Ratio Portfolio:")
print(max_sharpe_weights)
print("Expected Return:", portfolio_return(max_sharpe_weights))
print("Expected Variance:", portfolio_variance(max_sharpe_weights))
# Out:
# Weights for Minimum Variance Portfolio:
# [1.12652465e-01 1.79930171e-03 2.81877474e-02 2.46756303e-02
#  7.28452014e-02 1.96559089e-02 1.89735380e-18 4.33680869e-19
#  3.03576608e-18 1.21056299e-02 0.00000000e+00 0.00000000e+00
#  6.04716717e-03 6.17872775e-02 2.09301171e-02 1.73472348e-18
#  1.91395016e-01 0.00000000e+00 1.01958867e-02 1.51109370e-02
#  0.00000000e+00 1.46367293e-18 1.46477136e-01 3.38188429e-02
#  3.26153166e-02 7.03014327e-04 1.39595242e-03 1.30104261e-18
#  2.60208521e-18 1.12002009e-01 2.87313576e-18 2.51030197e-02
#  6.57510296e-02 4.74539283e-03 0.00000000e+00 0.00000000e+00]
# Expected Return: 0.0024907280148500433
# Expected Variance: 0.0010052617409338418
#
# Weights for Maximum Sharpe Ratio Portfolio:
# [2.26697413e-16 4.81813375e-16 0.00000000e+00 8.61493694e-16
#  0.00000000e+00 6.55374340e-16 0.00000000e+00 0.00000000e+00
#  4.97036394e-16 5.43897172e-16 4.21277767e-16 0.00000000e+00
#  0.00000000e+00 2.73490450e-16 7.19038105e-16 0.00000000e+00
#  5.83408903e-16 0.00000000e+00 7.30278853e-01 7.22714831e-16
#  2.69721147e-01 4.11806496e-16 5.35087314e-16 5.70808226e-16
#  4.39931616e-16 9.68050157e-16 5.80116006e-16 0.00000000e+00
#  0.00000000e+00 7.44674089e-16 0.00000000e+00 5.71581448e-16
#  5.53265002e-16 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# Expected Return: 0.006730915342440747
# Expected Variance: 0.002737696757901624

# %%
res={}
for i in range(num_assets):
  name=df.columns[i]
  res[name]=round(max_sharpe_weights[i],3)

filtered_res = {key: value for key, value in res.items() if value != 0}
filtered_res
# Out:
# {'RNDR': 0.73, 'WIF': 0.27}

# %%
portfolio_sum = 0

for key, value in filtered_res.items():
    portfolio_sum += returns[key] * value

portfolio_sum = portfolio_sum.fillna(0) 
# Plot the relative prices
plt.figure(figsize=(14, 8))

plt.plot(portfolio_sum.index, portfolio_sum.values, label='sum of relative prices')
plt.plot(eth_returns.index, eth_returns.values , label='eth returns')
plt.title('Price of Assets Relative to ETH')
plt.xlabel('Date')
plt.ylabel('Relative Price')
plt.ylim(-1, 1)
plt.xlim([datetime(2023,1 , 1), datetime(2024, 2, 1)])
plt.legend()
plt.show()

# Plot the relative prices
plt.figure(figsize=(14, 8))

plt.scatter(eth_returns.values, portfolio_sum.values , label='portfolio returns')
plt.plot(eth_returns.values, eth_returns.values , label='portfolio returns')
a,b = np.polyfit(x=eth_returns.values, y=portfolio_sum.values,deg=1)
plt.plot(eth_returns.values, a*eth_returns.values+b, label=f"a={round(a,2)}, b={round(b,2)}")
plt.title('Price of Assets Relative to ETH')
plt.xlabel('returns eth')
plt.ylabel('Relative Price')
plt.ylim(min(portfolio_sum.values),max(portfolio_sum.values))
plt.xlim()
plt.legend()
plt.show()

# %%
beta_total = 0
for key, value in filtered_res.items():
    print(key, beta_df[beta_df['Crypto']==key].Beta.values[0])
# Out:
# RNDR 1.1873456371427484
# WIF 0.4927524718600573

# %%
n = len(eth_returns.index)
portfolio_eth = np.zeros(n)
portfolio_assets = np.zeros(n)
v0 = 1000
portfolio_eth[0] = v0
portfolio_assets[0] = v0

for i in range (1, n):
    portfolio_eth[i] = (1+eth_returns[i-1])*portfolio_eth[i-1]
    portfolio_assets[i] = (1+portfolio_sum[i-1])*portfolio_assets[i-1]

# Plot
plt.figure(figsize=(14, 8))
plt.plot(portfolio_eth , label='portfolio Eth')
plt.plot(portfolio_assets , label='portfolio Assets')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Portfolio')
# Out:
# Text(0, 0.5, 'Portfolio')
